# %% [markdown]
# # Projekat

# %%
# ==========================================
# 🎭 EMOTION RECOGNITION - FER2013 (KaggleHub)
# ==========================================

# ===============================
# 1. UVOZ BIBLIOTEKA I DATASET
# ===============================
# !pip install kagglehub -q

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import kagglehub
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_recall_fscore_support
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

print(f"TensorFlow verzija: {tf.__version__}")
print(f"GPU dostupan: {len(tf.config.list_physical_devices('GPU')) > 0}")

# ===============================
# 2. PREUZIMANJE DATASETA SA KAGGLE
# ===============================
path = kagglehub.dataset_download("msambare/fer2013")
print("📁 Path to dataset files:", path)

# U fer2013 su već train/test folderi
train_dir = os.path.join(path, "train")
test_dir = os.path.join(path, "test")

# ===============================
# 3. PARAMETRI
# ===============================
IMG_SIZE = (48, 48)
BATCH_SIZE = 64
EPOCHS = 60
LEARNING_RATE = 0.001

emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
NUM_CLASSES = len(emotion_labels)

print(f"\n📊 Broj klasa: {NUM_CLASSES}")
print(f"🏷️ Emocije: {emotion_labels}")

# ===============================
# 4. DATA AUGMENTATION
# ===============================
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.25,
    shear_range=0.15,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=False
)

# ===============================
# 5. CNN MODEL
# ===============================
model = models.Sequential([
    # Block 1
    layers.Conv2D(64, (3,3), padding='same', kernel_initializer='he_normal', input_shape=(48, 48, 1)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(64, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(128, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(128, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.3),

    # Block 3
    layers.Conv2D(256, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(256, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.4),

    # Block 4
    layers.Conv2D(512, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.GlobalAveragePooling2D(),

    # Dense layers
    layers.Dense(512, kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(256, kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),

    # Output
    layers.Dense(NUM_CLASSES, activation='softmax')
])

optimizer = optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# ===============================
# 6. CALLBACKS
# ===============================
os.makedirs('models', exist_ok=True)

checkpoint = callbacks.ModelCheckpoint(
    'models/best_emotion_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stop = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

csv_logger = callbacks.CSVLogger('models/training_history.csv')
callbacks_list = [checkpoint, early_stop, reduce_lr, csv_logger]

# ===============================
# 7. TRENIRANJE
# ===============================
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=EPOCHS,
    callbacks=callbacks_list,
    verbose=1
)

model.save('models/final_emotion_model.keras')

# ===============================
# 8. GRAFICI
# ===============================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Loss')
plt.legend()

plt.savefig('models/training_curves.png', dpi=150)
plt.show()

# ===============================
# 9. EVALUACIJA
# ===============================
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('models/confusion_matrix.png', dpi=150)
plt.show()

report = classification_report(y_true, y_pred_classes, target_names=emotion_labels)
print(report)

with open('models/classification_report.txt', 'w') as f:
    f.write(report)

accuracy = accuracy_score(y_true, y_pred_classes)
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred_classes, average='weighted')

print(f"\n🎯 Accuracy: {accuracy:.4f}")
print(f"📏 Precision: {precision:.4f}")
print(f"📈 Recall: {recall:.4f}")
print(f"🔥 F1: {f1:.4f}")
print("\n✅ Modeli i rezultati sačuvani u folderu 'models/'")
# Out:
# TensorFlow verzija: 2.19.0
# GPU dostupan: True
# Using Colab cache for faster access to the 'fer2013' dataset.
# 📁 Path to dataset files: /kaggle/input/fer2013
#
# 📊 Broj klasa: 7
# 🏷️ Emocije: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,728,903 (10.41 MB)
#  Trainable params: 2,724,551 (10.39 MB)
#  Non-trainable params: 4,352 (17.00 KB)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.2007 - loss: 2.1155
# Epoch 1: val_accuracy improved from -inf to 0.25620, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 208s 423ms/step - accuracy: 0.2007 - loss: 2.1153 - val_accuracy: 0.2562 - val_loss: 1.7891 - learning_rate: 0.0010
# Epoch 2/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.2387 - loss: 1.8640
# Epoch 2: val_accuracy did not improve from 0.25620
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 53s 117ms/step - accuracy: 0.2387 - loss: 1.8639 - val_accuracy: 0.2198 - val_loss: 1.8044 - learning_rate: 0.0010
# Epoch 3/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.2528 - loss: 1.7999
# Epoch 3: val_accuracy improved from 0.25620 to 0.31764, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 117ms/step - accuracy: 0.2528 - loss: 1.7998 - val_accuracy: 0.3176 - val_loss: 1.6676 - learning_rate: 0.0010
# Epoch 4/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3037 - loss: 1.7085
# Epoch 4: val_accuracy improved from 0.31764 to 0.36751, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 116ms/step - accuracy: 0.3037 - loss: 1.7084 - val_accuracy: 0.3675 - val_loss: 1.6274 - learning_rate: 0.0010
# Epoch 5/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3966 - loss: 1.5482
# Epoch 5: val_accuracy improved from 0.36751 to 0.47102, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 116ms/step - accuracy: 0.3966 - loss: 1.5481 - val_accuracy: 0.4710 - val_loss: 1.3641 - learning_rate: 0.0010
# Epoch 6/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.4525 - loss: 1.4298
# Epoch 6: val_accuracy did not improve from 0.47102
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.4525 - loss: 1.4298 - val_accuracy: 0.4458 - val_loss: 1.4130 - learning_rate: 0.0010
# Epoch 7/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4791 - loss: 1.3620
# Epoch 7: val_accuracy improved from 0.47102 to 0.50181, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 117ms/step - accuracy: 0.4792 - loss: 1.3620 - val_accuracy: 0.5018 - val_loss: 1.2983 - learning_rate: 0.0010
# Epoch 8/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5032 - loss: 1.3160
# Epoch 8: val_accuracy did not improve from 0.50181
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.5033 - loss: 1.3159 - val_accuracy: 0.4852 - val_loss: 1.3169 - learning_rate: 0.0010
# Epoch 9/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5203 - loss: 1.2579
# Epoch 9: val_accuracy improved from 0.50181 to 0.56882, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.5203 - loss: 1.2578 - val_accuracy: 0.5688 - val_loss: 1.1344 - learning_rate: 0.0010
# Epoch 10/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5323 - loss: 1.2285
# Epoch 10: val_accuracy did not improve from 0.56882
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.5323 - loss: 1.2285 - val_accuracy: 0.5148 - val_loss: 1.2470 - learning_rate: 0.0010
# Epoch 11/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5428 - loss: 1.2069
# Epoch 11: val_accuracy improved from 0.56882 to 0.57593, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 116ms/step - accuracy: 0.5428 - loss: 1.2069 - val_accuracy: 0.5759 - val_loss: 1.1099 - learning_rate: 0.0010
# Epoch 12/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5514 - loss: 1.1861
# Epoch 12: val_accuracy improved from 0.57593 to 0.57690, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.5514 - loss: 1.1861 - val_accuracy: 0.5769 - val_loss: 1.0971 - learning_rate: 0.0010
# Epoch 13/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5564 - loss: 1.1748
# Epoch 13: val_accuracy did not improve from 0.57690
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.5564 - loss: 1.1748 - val_accuracy: 0.5756 - val_loss: 1.1155 - learning_rate: 0.0010
# Epoch 14/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5659 - loss: 1.1557
# Epoch 14: val_accuracy improved from 0.57690 to 0.60072, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.5659 - loss: 1.1557 - val_accuracy: 0.6007 - val_loss: 1.0437 - learning_rate: 0.0010
# Epoch 15/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5708 - loss: 1.1340
# Epoch 15: val_accuracy did not improve from 0.60072
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 116ms/step - accuracy: 0.5708 - loss: 1.1340 - val_accuracy: 0.5878 - val_loss: 1.0993 - learning_rate: 0.0010
# Epoch 16/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5812 - loss: 1.1345
# Epoch 16: val_accuracy did not improve from 0.60072
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.5811 - loss: 1.1345 - val_accuracy: 0.5933 - val_loss: 1.0797 - learning_rate: 0.0010
# Epoch 17/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5738 - loss: 1.1258
# Epoch 17: val_accuracy did not improve from 0.60072
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.5738 - loss: 1.1258 - val_accuracy: 0.5917 - val_loss: 1.0921 - learning_rate: 0.0010
# Epoch 18/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5799 - loss: 1.1139
# Epoch 18: val_accuracy did not improve from 0.60072
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 50s 112ms/step - accuracy: 0.5799 - loss: 1.1138 - val_accuracy: 0.5975 - val_loss: 1.0791 - learning_rate: 0.0010
# Epoch 19/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5878 - loss: 1.0942
# Epoch 19: val_accuracy did not improve from 0.60072
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.5878 - loss: 1.0942 - val_accuracy: 0.6004 - val_loss: 1.0614 - learning_rate: 0.0010
# Epoch 20/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5978 - loss: 1.0582
# Epoch 20: val_accuracy improved from 0.60072 to 0.63165, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.5978 - loss: 1.0582 - val_accuracy: 0.6317 - val_loss: 0.9750 - learning_rate: 5.0000e-04
# Epoch 21/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6092 - loss: 1.0378
# Epoch 21: val_accuracy improved from 0.63165 to 0.63444, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6091 - loss: 1.0378 - val_accuracy: 0.6344 - val_loss: 0.9611 - learning_rate: 5.0000e-04
# Epoch 22/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6139 - loss: 1.0342
# Epoch 22: val_accuracy improved from 0.63444 to 0.63834, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 124ms/step - accuracy: 0.6139 - loss: 1.0342 - val_accuracy: 0.6383 - val_loss: 0.9629 - learning_rate: 5.0000e-04
# Epoch 23/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6135 - loss: 1.0317
# Epoch 23: val_accuracy improved from 0.63834 to 0.64224, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.6135 - loss: 1.0317 - val_accuracy: 0.6422 - val_loss: 0.9569 - learning_rate: 5.0000e-04
# Epoch 24/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6173 - loss: 1.0251
# Epoch 24: val_accuracy improved from 0.64224 to 0.64628, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6173 - loss: 1.0251 - val_accuracy: 0.6463 - val_loss: 0.9526 - learning_rate: 5.0000e-04
# Epoch 25/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6184 - loss: 1.0207
# Epoch 25: val_accuracy did not improve from 0.64628
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6184 - loss: 1.0207 - val_accuracy: 0.6463 - val_loss: 0.9624 - learning_rate: 5.0000e-04
# Epoch 26/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6223 - loss: 1.0146
# Epoch 26: val_accuracy improved from 0.64628 to 0.64739, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6223 - loss: 1.0146 - val_accuracy: 0.6474 - val_loss: 0.9364 - learning_rate: 5.0000e-04
# Epoch 27/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6289 - loss: 1.0014
# Epoch 27: val_accuracy did not improve from 0.64739
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6289 - loss: 1.0015 - val_accuracy: 0.6442 - val_loss: 0.9452 - learning_rate: 5.0000e-04
# Epoch 28/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6241 - loss: 1.0202
# Epoch 28: val_accuracy did not improve from 0.64739
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6241 - loss: 1.0202 - val_accuracy: 0.6382 - val_loss: 0.9660 - learning_rate: 5.0000e-04
# Epoch 29/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6253 - loss: 1.0071
# Epoch 29: val_accuracy did not improve from 0.64739
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6253 - loss: 1.0071 - val_accuracy: 0.6413 - val_loss: 0.9659 - learning_rate: 5.0000e-04
# Epoch 30/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6285 - loss: 0.9915
# Epoch 30: val_accuracy improved from 0.64739 to 0.65018, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6285 - loss: 0.9915 - val_accuracy: 0.6502 - val_loss: 0.9437 - learning_rate: 5.0000e-04
# Epoch 31/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6227 - loss: 0.9954
# Epoch 31: val_accuracy did not improve from 0.65018
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6227 - loss: 0.9954 - val_accuracy: 0.6478 - val_loss: 0.9335 - learning_rate: 5.0000e-04
# Epoch 32/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6287 - loss: 0.9916
# Epoch 32: val_accuracy improved from 0.65018 to 0.65283, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6287 - loss: 0.9916 - val_accuracy: 0.6528 - val_loss: 0.9441 - learning_rate: 5.0000e-04
# Epoch 33/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6347 - loss: 0.9810
# Epoch 33: val_accuracy did not improve from 0.65283
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6347 - loss: 0.9810 - val_accuracy: 0.6408 - val_loss: 0.9714 - learning_rate: 5.0000e-04
# Epoch 34/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6393 - loss: 0.9575
# Epoch 34: val_accuracy did not improve from 0.65283
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6393 - loss: 0.9575 - val_accuracy: 0.6349 - val_loss: 0.9786 - learning_rate: 5.0000e-04
# Epoch 35/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6397 - loss: 0.9673
# Epoch 35: val_accuracy did not improve from 0.65283
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6397 - loss: 0.9674 - val_accuracy: 0.6485 - val_loss: 0.9426 - learning_rate: 5.0000e-04
# Epoch 36/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6385 - loss: 0.9650
# Epoch 36: val_accuracy did not improve from 0.65283
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6385 - loss: 0.9651 - val_accuracy: 0.6482 - val_loss: 0.9339 - learning_rate: 5.0000e-04
# Epoch 37/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6448 - loss: 0.9492
# Epoch 37: val_accuracy improved from 0.65283 to 0.66105, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 116ms/step - accuracy: 0.6448 - loss: 0.9492 - val_accuracy: 0.6610 - val_loss: 0.9079 - learning_rate: 2.5000e-04
# Epoch 38/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6472 - loss: 0.9399
# Epoch 38: val_accuracy did not improve from 0.66105
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6472 - loss: 0.9399 - val_accuracy: 0.6590 - val_loss: 0.9082 - learning_rate: 2.5000e-04
# Epoch 39/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6538 - loss: 0.9267
# Epoch 39: val_accuracy did not improve from 0.66105
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6538 - loss: 0.9268 - val_accuracy: 0.6598 - val_loss: 0.9120 - learning_rate: 2.5000e-04
# Epoch 40/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6539 - loss: 0.9286
# Epoch 40: val_accuracy improved from 0.66105 to 0.66467, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 116ms/step - accuracy: 0.6539 - loss: 0.9287 - val_accuracy: 0.6647 - val_loss: 0.9037 - learning_rate: 2.5000e-04
# Epoch 41/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6541 - loss: 0.9213
# Epoch 41: val_accuracy did not improve from 0.66467
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6541 - loss: 0.9213 - val_accuracy: 0.6605 - val_loss: 0.9132 - learning_rate: 2.5000e-04
# Epoch 42/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6517 - loss: 0.9300
# Epoch 42: val_accuracy did not improve from 0.66467
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6517 - loss: 0.9300 - val_accuracy: 0.6523 - val_loss: 0.9279 - learning_rate: 2.5000e-04
# Epoch 43/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6606 - loss: 0.9030
# Epoch 43: val_accuracy did not improve from 0.66467
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6606 - loss: 0.9030 - val_accuracy: 0.6595 - val_loss: 0.9245 - learning_rate: 2.5000e-04
# Epoch 44/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6558 - loss: 0.9154
# Epoch 44: val_accuracy improved from 0.66467 to 0.66885, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6558 - loss: 0.9154 - val_accuracy: 0.6688 - val_loss: 0.8924 - learning_rate: 2.5000e-04
# Epoch 45/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6607 - loss: 0.9147
# Epoch 45: val_accuracy did not improve from 0.66885
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6607 - loss: 0.9148 - val_accuracy: 0.6617 - val_loss: 0.9130 - learning_rate: 2.5000e-04
# Epoch 46/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6626 - loss: 0.9137
# Epoch 46: val_accuracy improved from 0.66885 to 0.66941, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6626 - loss: 0.9137 - val_accuracy: 0.6694 - val_loss: 0.9090 - learning_rate: 2.5000e-04
# Epoch 47/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6571 - loss: 0.9157
# Epoch 47: val_accuracy did not improve from 0.66941
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6571 - loss: 0.9157 - val_accuracy: 0.6666 - val_loss: 0.9075 - learning_rate: 2.5000e-04
# Epoch 48/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6572 - loss: 0.9077
# Epoch 48: val_accuracy did not improve from 0.66941
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 53s 118ms/step - accuracy: 0.6572 - loss: 0.9077 - val_accuracy: 0.6592 - val_loss: 0.9132 - learning_rate: 2.5000e-04
# Epoch 49/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6618 - loss: 0.9094
# Epoch 49: val_accuracy did not improve from 0.66941
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6618 - loss: 0.9094 - val_accuracy: 0.6633 - val_loss: 0.9096 - learning_rate: 2.5000e-04
# Epoch 50/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6615 - loss: 0.9097
# Epoch 50: val_accuracy did not improve from 0.66941
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6615 - loss: 0.9097 - val_accuracy: 0.6654 - val_loss: 0.9020 - learning_rate: 1.2500e-04
# Epoch 51/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6602 - loss: 0.9046
# Epoch 51: val_accuracy improved from 0.66941 to 0.66996, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6602 - loss: 0.9046 - val_accuracy: 0.6700 - val_loss: 0.8831 - learning_rate: 1.2500e-04
# Epoch 52/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6656 - loss: 0.8979
# Epoch 52: val_accuracy improved from 0.66996 to 0.67052, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6656 - loss: 0.8980 - val_accuracy: 0.6705 - val_loss: 0.8870 - learning_rate: 1.2500e-04
# Epoch 53/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6658 - loss: 0.8898
# Epoch 53: val_accuracy did not improve from 0.67052
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 113ms/step - accuracy: 0.6658 - loss: 0.8898 - val_accuracy: 0.6693 - val_loss: 0.8959 - learning_rate: 1.2500e-04
# Epoch 54/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6682 - loss: 0.8906
# Epoch 54: val_accuracy did not improve from 0.67052
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6682 - loss: 0.8906 - val_accuracy: 0.6680 - val_loss: 0.8981 - learning_rate: 1.2500e-04
# Epoch 55/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6728 - loss: 0.8850
# Epoch 55: val_accuracy improved from 0.67052 to 0.67512, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6728 - loss: 0.8850 - val_accuracy: 0.6751 - val_loss: 0.8869 - learning_rate: 1.2500e-04
# Epoch 56/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6673 - loss: 0.8874
# Epoch 56: val_accuracy did not improve from 0.67512
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.6673 - loss: 0.8874 - val_accuracy: 0.6693 - val_loss: 0.9047 - learning_rate: 1.2500e-04
# Epoch 57/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6717 - loss: 0.8883
# Epoch 57: val_accuracy did not improve from 0.67512
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6717 - loss: 0.8883 - val_accuracy: 0.6747 - val_loss: 0.8889 - learning_rate: 6.2500e-05
# Epoch 58/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6745 - loss: 0.8772
# Epoch 58: val_accuracy did not improve from 0.67512
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 54s 119ms/step - accuracy: 0.6745 - loss: 0.8772 - val_accuracy: 0.6746 - val_loss: 0.8857 - learning_rate: 6.2500e-05
# Epoch 59/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6706 - loss: 0.8853
# Epoch 59: val_accuracy did not improve from 0.67512
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 117ms/step - accuracy: 0.6707 - loss: 0.8853 - val_accuracy: 0.6702 - val_loss: 0.8954 - learning_rate: 6.2500e-05
# Epoch 60/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6777 - loss: 0.8681
# Epoch 60: val_accuracy did not improve from 0.67512
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 115ms/step - accuracy: 0.6777 - loss: 0.8681 - val_accuracy: 0.6728 - val_loss: 0.8884 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 55.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step
#               precision    recall  f1-score   support
#
#        angry       0.59      0.63      0.61       958
#      disgust       0.62      0.54      0.58       111
#         fear       0.58      0.38      0.46      1024
#        happy       0.90      0.87      0.89      1774
#      neutral       0.54      0.75      0.63      1233
#          sad       0.58      0.53      0.56      1247
#     surprise       0.79      0.80      0.79       831
#
#     accuracy                           0.68      7178
#    macro avg       0.66      0.64      0.64      7178
# weighted avg       0.68      0.68      0.67      7178
#
#
# 🎯 Accuracy: 0.6751
# 📏 Precision: 0.6800
# 📈 Recall: 0.6751
# 🔥 F1: 0.6712
#
# ✅ Modeli i rezultati sačuvani u folderu 'models/'
