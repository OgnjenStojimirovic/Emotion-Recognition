# %% [markdown]
# # Projekat

# %%
# ==========================================
# 🎭 EMOTION RECOGNITION - FER2013 (KaggleHub)
# ==========================================

# ===============================
# 1. UVOZ BIBLIOTEKA I DATASET
# ===============================
# !pip install kagglehub -q

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import kagglehub
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_recall_fscore_support
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

print(f"TensorFlow verzija: {tf.__version__}")
print(f"GPU dostupan: {len(tf.config.list_physical_devices('GPU')) > 0}")

# ===============================
# 2. PREUZIMANJE DATASETA SA KAGGLE
# ===============================
path = kagglehub.dataset_download("msambare/fer2013")
print("📁 Path to dataset files:", path)

# U fer2013 su već train/test folderi
train_dir = os.path.join(path, "train")
test_dir = os.path.join(path, "test")

# ===============================
# 3. PARAMETRI
# ===============================
IMG_SIZE = (48, 48)
BATCH_SIZE = 64
EPOCHS = 40
LEARNING_RATE = 0.001

emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
NUM_CLASSES = len(emotion_labels)

print(f"\n📊 Broj klasa: {NUM_CLASSES}")
print(f"🏷️ Emocije: {emotion_labels}")

# ===============================
# 4. DATA AUGMENTATION
# ===============================
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.25,
    shear_range=0.15,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=False
)

# ===============================
# 5. CNN MODEL
# ===============================
model = models.Sequential([
    # Block 1
    layers.Conv2D(64, (3,3), padding='same', kernel_initializer='he_normal', input_shape=(48, 48, 1)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(64, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(128, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(128, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.3),

    # Block 3
    layers.Conv2D(256, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(256, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.4),

    # Block 4
    layers.Conv2D(512, (3,3), padding='same', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.GlobalAveragePooling2D(),

    # Dense layers
    layers.Dense(512, kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(256, kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),

    # Output
    layers.Dense(NUM_CLASSES, activation='softmax')
])

optimizer = optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# ===============================
# 6. CALLBACKS
# ===============================
os.makedirs('models', exist_ok=True)

checkpoint = callbacks.ModelCheckpoint(
    'models/best_emotion_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stop = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

csv_logger = callbacks.CSVLogger('models/training_history.csv')
callbacks_list = [checkpoint, early_stop, reduce_lr, csv_logger]

# ===============================
# 7. TRENIRANJE
# ===============================
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=EPOCHS,
    callbacks=callbacks_list,
    verbose=1
)

model.save('models/final_emotion_model.keras')

# ===============================
# 8. GRAFICI
# ===============================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Loss')
plt.legend()

plt.savefig('models/training_curves.png', dpi=150)
plt.show()

# ===============================
# 9. EVALUACIJA
# ===============================
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('models/confusion_matrix.png', dpi=150)
plt.show()

report = classification_report(y_true, y_pred_classes, target_names=emotion_labels)
print(report)

with open('models/classification_report.txt', 'w') as f:
    f.write(report)

accuracy = accuracy_score(y_true, y_pred_classes)
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred_classes, average='weighted')

print(f"\n🎯 Accuracy: {accuracy:.4f}")
print(f"📏 Precision: {precision:.4f}")
print(f"📈 Recall: {recall:.4f}")
print(f"🔥 F1: {f1:.4f}")
print("\n✅ Modeli i rezultati sačuvani u folderu 'models/'")
# Out:
# TensorFlow verzija: 2.19.0
# GPU dostupan: True
# Using Colab cache for faster access to the 'fer2013' dataset.
# 📁 Path to dataset files: /kaggle/input/fer2013
#
# 📊 Broj klasa: 7
# 🏷️ Emocije: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,728,903 (10.41 MB)
#  Trainable params: 2,724,551 (10.39 MB)
#  Non-trainable params: 4,352 (17.00 KB)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.2055 - loss: 2.0995
# Epoch 1: val_accuracy improved from -inf to 0.25063, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 215s 439ms/step - accuracy: 0.2056 - loss: 2.0993 - val_accuracy: 0.2506 - val_loss: 1.8010 - learning_rate: 0.0010
# Epoch 2/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2289 - loss: 1.8699
# Epoch 2: val_accuracy improved from 0.25063 to 0.26930, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 48s 106ms/step - accuracy: 0.2290 - loss: 1.8698 - val_accuracy: 0.2693 - val_loss: 1.7712 - learning_rate: 0.0010
# Epoch 3/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.2754 - loss: 1.7727
# Epoch 3: val_accuracy did not improve from 0.26930
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 104ms/step - accuracy: 0.2754 - loss: 1.7726 - val_accuracy: 0.2508 - val_loss: 1.9346 - learning_rate: 0.0010
# Epoch 4/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.3339 - loss: 1.6512
# Epoch 4: val_accuracy improved from 0.26930 to 0.32683, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 105ms/step - accuracy: 0.3339 - loss: 1.6511 - val_accuracy: 0.3268 - val_loss: 1.7908 - learning_rate: 0.0010
# Epoch 5/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.4120 - loss: 1.5171
# Epoch 5: val_accuracy improved from 0.32683 to 0.48440, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 104ms/step - accuracy: 0.4120 - loss: 1.5171 - val_accuracy: 0.4844 - val_loss: 1.3651 - learning_rate: 0.0010
# Epoch 6/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.4572 - loss: 1.4148
# Epoch 6: val_accuracy improved from 0.48440 to 0.49150, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 104ms/step - accuracy: 0.4572 - loss: 1.4148 - val_accuracy: 0.4915 - val_loss: 1.3203 - learning_rate: 0.0010
# Epoch 7/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.4828 - loss: 1.3463
# Epoch 7: val_accuracy improved from 0.49150 to 0.50348, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 105ms/step - accuracy: 0.4828 - loss: 1.3462 - val_accuracy: 0.5035 - val_loss: 1.2651 - learning_rate: 0.0010
# Epoch 8/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5074 - loss: 1.2933
# Epoch 8: val_accuracy improved from 0.50348 to 0.53274, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5074 - loss: 1.2933 - val_accuracy: 0.5327 - val_loss: 1.1974 - learning_rate: 0.0010
# Epoch 9/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5164 - loss: 1.2724
# Epoch 9: val_accuracy improved from 0.53274 to 0.55433, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5164 - loss: 1.2724 - val_accuracy: 0.5543 - val_loss: 1.1691 - learning_rate: 0.0010
# Epoch 10/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5363 - loss: 1.2239
# Epoch 10: val_accuracy did not improve from 0.55433
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.5363 - loss: 1.2239 - val_accuracy: 0.5451 - val_loss: 1.2357 - learning_rate: 0.0010
# Epoch 11/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5442 - loss: 1.2064
# Epoch 11: val_accuracy did not improve from 0.55433
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.5442 - loss: 1.2064 - val_accuracy: 0.5301 - val_loss: 1.2838 - learning_rate: 0.0010
# Epoch 12/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5509 - loss: 1.1823
# Epoch 12: val_accuracy improved from 0.55433 to 0.59209, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5509 - loss: 1.1823 - val_accuracy: 0.5921 - val_loss: 1.0568 - learning_rate: 0.0010
# Epoch 13/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5589 - loss: 1.1633
# Epoch 13: val_accuracy improved from 0.59209 to 0.60476, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5589 - loss: 1.1633 - val_accuracy: 0.6048 - val_loss: 1.0442 - learning_rate: 0.0010
# Epoch 14/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5710 - loss: 1.1493
# Epoch 14: val_accuracy did not improve from 0.60476
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5710 - loss: 1.1493 - val_accuracy: 0.5841 - val_loss: 1.0942 - learning_rate: 0.0010
# Epoch 15/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5690 - loss: 1.1416
# Epoch 15: val_accuracy did not improve from 0.60476
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 105ms/step - accuracy: 0.5690 - loss: 1.1416 - val_accuracy: 0.5711 - val_loss: 1.1370 - learning_rate: 0.0010
# Epoch 16/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5716 - loss: 1.1286
# Epoch 16: val_accuracy improved from 0.60476 to 0.60908, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5716 - loss: 1.1286 - val_accuracy: 0.6091 - val_loss: 1.0459 - learning_rate: 0.0010
# Epoch 17/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5827 - loss: 1.1003
# Epoch 17: val_accuracy did not improve from 0.60908
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5827 - loss: 1.1003 - val_accuracy: 0.6057 - val_loss: 1.0374 - learning_rate: 0.0010
# Epoch 18/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5801 - loss: 1.1114
# Epoch 18: val_accuracy improved from 0.60908 to 0.61814, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5801 - loss: 1.1114 - val_accuracy: 0.6181 - val_loss: 0.9993 - learning_rate: 0.0010
# Epoch 19/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5869 - loss: 1.1002
# Epoch 19: val_accuracy improved from 0.61814 to 0.62594, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 104ms/step - accuracy: 0.5869 - loss: 1.1001 - val_accuracy: 0.6259 - val_loss: 0.9818 - learning_rate: 0.0010
# Epoch 20/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5964 - loss: 1.0723
# Epoch 20: val_accuracy did not improve from 0.62594
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.5964 - loss: 1.0724 - val_accuracy: 0.6074 - val_loss: 1.0436 - learning_rate: 0.0010
# Epoch 21/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5961 - loss: 1.0720
# Epoch 21: val_accuracy did not improve from 0.62594
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.5961 - loss: 1.0720 - val_accuracy: 0.6103 - val_loss: 1.0499 - learning_rate: 0.0010
# Epoch 22/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6026 - loss: 1.0603
# Epoch 22: val_accuracy did not improve from 0.62594
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.6026 - loss: 1.0603 - val_accuracy: 0.6241 - val_loss: 0.9969 - learning_rate: 0.0010
# Epoch 23/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5978 - loss: 1.0729
# Epoch 23: val_accuracy improved from 0.62594 to 0.63318, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 105ms/step - accuracy: 0.5978 - loss: 1.0729 - val_accuracy: 0.6332 - val_loss: 0.9667 - learning_rate: 0.0010
# Epoch 24/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6064 - loss: 1.0512
# Epoch 24: val_accuracy did not improve from 0.63318
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 45s 101ms/step - accuracy: 0.6064 - loss: 1.0512 - val_accuracy: 0.6059 - val_loss: 1.0312 - learning_rate: 0.0010
# Epoch 25/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6143 - loss: 1.0382
# Epoch 25: val_accuracy did not improve from 0.63318
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 45s 101ms/step - accuracy: 0.6143 - loss: 1.0382 - val_accuracy: 0.6275 - val_loss: 0.9706 - learning_rate: 0.0010
# Epoch 26/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6182 - loss: 1.0326
# Epoch 26: val_accuracy did not improve from 0.63318
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6182 - loss: 1.0326 - val_accuracy: 0.6289 - val_loss: 0.9924 - learning_rate: 0.0010
# Epoch 27/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6168 - loss: 1.0253
# Epoch 27: val_accuracy improved from 0.63318 to 0.63625, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.6168 - loss: 1.0253 - val_accuracy: 0.6362 - val_loss: 0.9751 - learning_rate: 0.0010
# Epoch 28/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6208 - loss: 1.0121
# Epoch 28: val_accuracy did not improve from 0.63625
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6208 - loss: 1.0122 - val_accuracy: 0.6350 - val_loss: 0.9656 - learning_rate: 0.0010
# Epoch 29/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6183 - loss: 1.0090
# Epoch 29: val_accuracy did not improve from 0.63625
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6183 - loss: 1.0091 - val_accuracy: 0.6232 - val_loss: 1.0006 - learning_rate: 0.0010
# Epoch 30/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6244 - loss: 1.0024
# Epoch 30: val_accuracy improved from 0.63625 to 0.64865, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6244 - loss: 1.0024 - val_accuracy: 0.6486 - val_loss: 0.9545 - learning_rate: 0.0010
# Epoch 31/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6238 - loss: 0.9963
# Epoch 31: val_accuracy did not improve from 0.64865
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6238 - loss: 0.9963 - val_accuracy: 0.6467 - val_loss: 0.9491 - learning_rate: 0.0010
# Epoch 32/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6228 - loss: 1.0030
# Epoch 32: val_accuracy did not improve from 0.64865
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6228 - loss: 1.0030 - val_accuracy: 0.6319 - val_loss: 0.9680 - learning_rate: 0.0010
# Epoch 33/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6279 - loss: 0.9902
# Epoch 33: val_accuracy did not improve from 0.64865
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6279 - loss: 0.9902 - val_accuracy: 0.6372 - val_loss: 0.9735 - learning_rate: 0.0010
# Epoch 34/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6350 - loss: 0.9836
# Epoch 34: val_accuracy did not improve from 0.64865
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.6350 - loss: 0.9836 - val_accuracy: 0.6402 - val_loss: 0.9515 - learning_rate: 0.0010
# Epoch 35/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6286 - loss: 0.9901
# Epoch 35: val_accuracy improved from 0.64865 to 0.65311, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 45s 101ms/step - accuracy: 0.6286 - loss: 0.9901 - val_accuracy: 0.6531 - val_loss: 0.9436 - learning_rate: 0.0010
# Epoch 36/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6370 - loss: 0.9832
# Epoch 36: val_accuracy did not improve from 0.65311
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6370 - loss: 0.9832 - val_accuracy: 0.6262 - val_loss: 1.0416 - learning_rate: 0.0010
# Epoch 37/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6362 - loss: 0.9768
# Epoch 37: val_accuracy did not improve from 0.65311
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6362 - loss: 0.9768 - val_accuracy: 0.6486 - val_loss: 0.9431 - learning_rate: 0.0010
# Epoch 38/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6453 - loss: 0.9525
# Epoch 38: val_accuracy did not improve from 0.65311
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - accuracy: 0.6453 - loss: 0.9526 - val_accuracy: 0.6475 - val_loss: 0.9398 - learning_rate: 0.0010
# Epoch 39/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6374 - loss: 0.9766
# Epoch 39: val_accuracy did not improve from 0.65311
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 45s 101ms/step - accuracy: 0.6374 - loss: 0.9766 - val_accuracy: 0.6474 - val_loss: 0.9260 - learning_rate: 0.0010
# Epoch 40/40
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6464 - loss: 0.9436
# Epoch 40: val_accuracy improved from 0.65311 to 0.65826, saving model to models/best_emotion_model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 46s 102ms/step - accuracy: 0.6464 - loss: 0.9437 - val_accuracy: 0.6583 - val_loss: 0.9335 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 40.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step
#               precision    recall  f1-score   support
#
#        angry       0.49      0.72      0.58       958
#      disgust       0.57      0.32      0.41       111
#         fear       0.51      0.40      0.45      1024
#        happy       0.87      0.89      0.88      1774
#      neutral       0.63      0.63      0.63      1233
#          sad       0.56      0.51      0.54      1247
#     surprise       0.83      0.69      0.76       831
#
#     accuracy                           0.66      7178
#    macro avg       0.64      0.60      0.61      7178
# weighted avg       0.66      0.66      0.66      7178
#
#
# 🎯 Accuracy: 0.6583
# 📏 Precision: 0.6643
# 📈 Recall: 0.6583
# 🔥 F1: 0.6559
#
# ✅ Modeli i rezultati sačuvani u folderu 'models/'
